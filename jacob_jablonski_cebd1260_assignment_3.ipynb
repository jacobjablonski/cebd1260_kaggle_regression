# %% [markdown]
# # Import Libraries

# %%
# import the library
# %matplotlib inline

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# sklearn :: utils
from sklearn.model_selection import train_test_split

# sklearn :: models
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.datasets import make_regression
from sklearn.neighbors import KNeighborsRegressor

# sklearn :: evaluation metrics
from sklearn.metrics import mean_squared_error

sns.set_style('whitegrid')

# %% [markdown]
# # Problem Definition
# Predict Airbnb prices in makor US cities

# %% [markdown]
# # Import the data set

# %%
df_train = pd.read_csv('train.csv')
df_test = pd.read_csv('test.csv')
print(df_train.shape, df_test.shape)
# Out:
# (51000, 29) (23111, 28)

# %% [markdown]
# # Feature Engineering

# %%
print(df_train.columns)
df_train.head()
# Out:
# Index(['id', 'log_price', 'property_type', 'room_type', 'amenities',
#        'accommodates', 'bathrooms', 'bed_type', 'cancellation_policy',
#        'cleaning_fee', 'city', 'description', 'first_review',
#        'host_has_profile_pic', 'host_identity_verified', 'host_response_rate',
#        'host_since', 'instant_bookable', 'last_review', 'latitude',
#        'longitude', 'name', 'neighbourhood', 'number_of_reviews',
#        'review_scores_rating', 'thumbnail_url', 'zipcode', 'bedrooms', 'beds'],
#       dtype='object')
#          id  log_price property_type        room_type  \
# 0  13662370   3.806662         House     Private room
# 1   4765892   4.941642     Apartment  Entire home/apt
# 2  21169968   4.941642     Apartment  Entire home/apt
# 3   7939196   4.867534     Apartment  Entire home/apt
# 4  18161036   3.663562         House     Private room
#
#                                            amenities  accommodates  bathrooms  \
# 0  {TV,Internet,"Wireless Internet","Air conditio...             2        1.5
# 1  {TV,Internet,"Wireless Internet","Air conditio...             2        2.0
# 2  {TV,"Cable TV","Wireless Internet","Air condit...             5        1.0
# 3  {"Cable TV",Internet,"Wireless Internet","Air ...             6        1.0
# 4  {Internet,"Wireless Internet","Air conditionin...             2        1.0
#
#    bed_type cancellation_policy  cleaning_fee  ...    latitude   longitude  \
# 0  Real Bed              strict          True  ...   41.849684  -87.676270
# 1  Real Bed              strict          True  ...   34.068613 -118.246455
# 2  Real Bed            moderate          True  ...   40.701958  -73.917352
# 3  Real Bed              strict          True  ...   40.742959  -73.990820
# 4  Real Bed            flexible          True  ...   34.046473 -117.734095
#
#                                              name      neighbourhood  \
# 0               Pilsen Arts Community Custom Home             Pilsen
# 1  Apartment 5 minutes from DTLA & Dodger Stadium          Echo Park
# 2  Brand New Huge 2bdr apartment(L,M train 2 min)           Bushwick
# 3                      Grande Super Large APT !!!  Flatiron District
# 4          Private Cozy and Clean Rooms in Pomona                NaN
#
#   number_of_reviews review_scores_rating  \
# 0                17                 97.0
# 1                 2                100.0
# 2                25                 88.0
# 3                12                 82.0
# 4                 2                100.0
#
#                                        thumbnail_url zipcode bedrooms  beds
# 0  https://a0.muscache.com/im/pictures/81318153/a...   60608      1.0   1.0
# 1  https://a0.muscache.com/im/pictures/aa00250e-0...   90012      1.0   1.0
# 2  https://a0.muscache.com/im/pictures/d9220535-c...   11237      2.0   3.0
# 3                                                NaN   10010      1.0   3.0
# 4  https://a0.muscache.com/im/pictures/e0c9b2f9-a...   91766      1.0   1.0
#
# [5 rows x 29 columns]

# %%
# select the columns
X_columns = ['accommodates', 'bathrooms', 'bedrooms', 'beds', 'review_scores_rating']
y_column = ['log_price']

# %%
# handle missing values
df_train = df_train[X_columns + y_column]
print(df_train.shape)
df_train = df_train.fillna(0.0) # probably not a good idea for 'review_scores_rating'
print(df_train.shape)
# Out:
# (51000, 6)
# (51000, 6)

# %% [markdown]
# # Model Training

# %%
# split the data using sklearn

threshold = 0.8
X = df_train[X_columns]
y = df_train[y_column]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=1.0-threshold, shuffle=True)

print('X_train', X_train.shape)
print('y_train', y_train.shape)
print('X_test', X_test.shape)
print('y_test', y_test.shape)
# Out:
# X_train (40800, 5)
# y_train (40800, 1)
# X_test (10200, 5)
# y_test (10200, 1)

# %%
# train a regression
model = RandomForestRegressor(n_estimators=100)
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
# Out:
# /Users/jacobjablonski/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
# split the data using sklearn

threshold = 0.8
X = df_train[X_columns]
y = df_train[y_column]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=1.0-threshold, shuffle=True)

print('X_train', X_train.shape)
print('y_train', y_train.shape)
print('X_test', X_test.shape)
print('y_test', y_test.shape)
# Out:
# X_train (40800, 5)
# y_train (40800, 1)
# X_test (10200, 5)
# y_test (10200, 1)

# %% [markdown]
# # Model Evaluation

# %%
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
print('RMSE', round(rmse, 2))
plt.scatter(y_test, y_pred, alpha=0.3)
plt.plot(range(0,10), range(0,10), '--r', alpha=0.3, label='Line1')
plt.title('RandomForestRegressor')
plt.xlabel('True Value')
plt.ylabel('Predict Value')
plt.show()
# Out:
# RMSE 0.88

# %% [markdown]
# # Prepare csv upload

# %%
df_prediction = df_test[X_columns].fillna(0.0)
df_test['log_price'] = model.predict(df_prediction)
df_test[['id', 'log_price']]
# Out:
#              id  log_price
# 0        986942   4.542159
# 1      16436737   4.765591
# 2      18209634   4.060619
# 3      15027024   4.646646
# 4      18074243   5.263843
# 5       8446914   4.552460
# 6      19362916   5.290555
# 7      16116059   5.508640
# 8      20912583   4.646646
# 9      13573101   4.965809
# 10     15938749   5.346075
# 11     13659214   4.276873
# 12      6239753   4.715662
# 13     11627400   5.144121
# 14     17794295   5.080795
# 15     15267276   5.157204
# 16      9476370   5.025335
# 17     14694999   5.233217
# 18     19847012   5.047768
# 19      8860277   4.542159
# 20      2975445   5.514627
# 21      1390712   4.969136
# 22     16144412   4.211607
# 23      1312673   4.882035
# 24      6645473   4.542159
# 25      7227023   5.541009
# 26     17283456   5.144121
# 27     13719227   4.509857
# 28     11413078   4.197663
# 29     15166399   4.646646
# ...         ...        ...
# 23081    840797   5.757641
# 23082   4880277   4.104791
# 23083  12816576   4.646646
# 23084  11626561   5.025335
# 23085  10051649   4.542159
# 23086  18406772   5.567573
# 23087   8776928   4.542159
# 23088   2811061   4.894872
# 23089  14606464   4.542159
# 23090   8564722   5.454637
# 23091    808919   4.552460
# 23092  10035324   5.461119
# 23093   1480015   6.468071
# 23094   8847624   5.025335
# 23095  18618632   3.801101
# 23096   6425382   4.378608
# 23097   7674543   4.778119
# 23098  12585689   6.395655
# 23099  17299278   4.104791
# 23100  18210259   5.017248
# 23101   1226155   4.470388
# 23102  16930596   4.506917
# 23103  10679702   4.778119
# 23104  13319386   4.542159
# 23105  18820769   5.573817
# 23106  15101498   4.470388
# 23107    298258   4.064436
# 23108   4917508   5.293802
# 23109  16645828   4.646646
# 23110  17797691   4.542159
#
# [23111 rows x 2 columns]

# %%
df_test[['id', 'log_price']].to_csv('submission_randomtree_regression.csv', index=False)
